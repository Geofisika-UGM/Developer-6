# %%
from parabola import parabola
parabola(100,15,0,0)
parabola(100,5,0,0)
# Out:
# start =  0.0 stop =  5.382021328622871 step =  0.1
# Waktu Analitik ketika menyentuh tanah :  5.300000000000001
# Jarak Maksimal dari Analitik  511.9406879332062
#
#
# Waktu Total :  5.282021328622871
# Jarak Maksimum :  510.2040816326529
# Tinggi Maksimum :  34.17719291213299
# start =  0.0 stop =  1.878688627503228 step =  0.1
# Waktu Analitik ketika menyentuh tanah :  1.8
# Jarak Maksimal dari Analitik  179.3150456565142
#
#
# Waktu Total :  1.7786886275032279
# Jarak Maksimum :  177.19201802747995
# Tinggi Maksimum :  3.8755732111714125
